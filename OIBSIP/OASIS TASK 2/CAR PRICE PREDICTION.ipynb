# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cpp = pd.read_csv('car data.csv')

# %%
cpp
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
cpp.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
cpp.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
cpp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
print (cpp['Selling_type'].unique())
print (cpp['Fuel_Type'].unique())
print(cpp['Transmission'].unique())
print(cpp['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
cpp.duplicated().sum()
# Out:
# 2

# %%
cpp.drop_duplicates(inplace=True)

# %%
cpp.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
cpp['Year']=pd.to_datetime(cpp['Year'], format = '%Y').dt.year

# %%
cpp['Owner'] = cpp['Owner'].astype('int32')
cpp['Driven_kms'] = cpp['Driven_kms'].astype('int32')

# %%
cpp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    object
#  1   Year           299 non-null    int32
#  2   Selling_Price  299 non-null    float64
#  3   Present_Price  299 non-null    float64
#  4   Driven_kms     299 non-null    int32
#  5   Fuel_Type      299 non-null    object
#  6   Selling_type   299 non-null    object
#  7   Transmission   299 non-null    object
#  8   Owner          299 non-null    int32
# dtypes: float64(2), int32(3), object(4)
# memory usage: 19.9+ KB

# %%
cpp['Year'].unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007])

# %%
cpp['Year'].nunique()
# Out:
# 16

# %%
cpp = cpp.drop(columns = 'Car_Name')

# %%
cpp['current year'] = 2023

# %%
cpp['Age of car'] = cpp['current year']-cpp['Year']

# %%
cpp
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  current year  Age of car
# ...

# %%
cpp = cpp.drop(columns = ['current year', 'Year'])

# %%
cpp
# Out:
#      Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0             3.35           5.59       27000    Petrol       Dealer
# 1             4.75           9.54       43000    Diesel       Dealer
# 2             7.25           9.85        6900    Petrol       Dealer
# 3             2.85           4.15        5200    Petrol       Dealer
# 4             4.60           6.87       42450    Diesel       Dealer
# ..             ...            ...         ...       ...          ...
# 296           9.50          11.60       33988    Diesel       Dealer
# 297           4.00           5.90       60000    Petrol       Dealer
# 298           3.35          11.00       87934    Petrol       Dealer
# 299          11.50          12.50        9000    Diesel       Dealer
# 300           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  Age of car
# 0         Manual      0           9
# 1         Manual      0          10
# ...

# %%
cpp = pd.get_dummies(data = cpp, drop_first=True)

# %%
cpp
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  Age of car  \
# 0             3.35           5.59       27000      0           9
# 1             4.75           9.54       43000      0          10
# 2             7.25           9.85        6900      0           6
# 3             2.85           4.15        5200      0          12
# 4             4.60           6.87       42450      0           9
# ..             ...            ...         ...    ...         ...
# 296           9.50          11.60       33988      0           7
# 297           4.00           5.90       60000      0           8
# 298           3.35          11.00       87934      0          14
# 299          11.50          12.50        9000      0           6
# 300           5.30           5.90        5464      0           7
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0               False              True                    False
# ...

# %%
m = ['Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Selling_type_Individual', 'Transmission_Manual']
cpp[m] = cpp[m].astype('int')

# %%
cpp.head(5)
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Age of car  \
# 0           3.35           5.59       27000      0           9
# 1           4.75           9.54       43000      0          10
# 2           7.25           9.85        6900      0           6
# 3           2.85           4.15        5200      0          12
# 4           4.60           6.87       42450      0           9
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0                 0                 1                        0
# 1                 1                 0                        0
# 2                 0                 1                        0
# 3                 0                 1                        0
# 4                 1                 0                        0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
cpp.corr()
# Out:
#                          Selling_Price  Present_Price  Driven_kms     Owner  \
# Selling_Price                 1.000000       0.876305    0.028566 -0.087880
# Present_Price                 0.876305       1.000000    0.205224  0.009948
# Driven_kms                    0.028566       0.205224    1.000000  0.089367
# Owner                        -0.087880       0.009948    0.089367  1.000000
# Age of car                   -0.234369       0.053167    0.525714  0.181639
# Fuel_Type_Diesel              0.543541       0.464934    0.173295 -0.051836
# Fuel_Type_Petrol             -0.531636      -0.456829   -0.173595  0.054102
# Selling_type_Individual      -0.553851      -0.511779   -0.101030  0.123646
# Transmission_Manual          -0.348869      -0.334326   -0.163881 -0.052166
#
#                          Age of car  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price             -0.234369          0.543541         -0.531636
# ...

# %%
Categorical_features = [col for col in cpp.columns if cpp[col].dtype == '0']
Categorical_features
# Out:
# []

# %%
Numerical_features = [col for col in cpp.columns if cpp[col].dtype !='0']
Numerical_features
# Out:
# ['Selling_Price',
#  'Present_Price',
#  'Driven_kms',
#  'Owner',
#  'Age of car',
#  'Fuel_Type_Diesel',
#  'Fuel_Type_Petrol',
#  'Selling_type_Individual',
#  'Transmission_Manual']

# %%
plt.figure(figsize=(20,25), facecolor='pink')
plotnumber =1

for column in Numerical_features:
    if plotnumber<=3:
        ax= plt.subplot(5,5,plotnumber)
        sns.countplot(x = column, data = cpp)
        plt.xlabel(column,fontsize=25)
    plotnumber+=1
plt.tight_layout()

# %%
import warnings
warnings.filterwarnings('ignore')
sns.pairplot(cpp)

# %%
sns.heatmap(cpp.corr(), annot=True, cmap = 'Blues')
# Out:
# <Axes: >

# %%
y=cpp['Selling_Price']
x=cpp.drop(columns=['Selling_Price'])

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
x
# Out:
#      Present_Price  Driven_kms  Owner  Age of car  Fuel_Type_Diesel  \
# 0             5.59       27000      0           9                 0
# 1             9.54       43000      0          10                 1
# 2             9.85        6900      0           6                 0
# 3             4.15        5200      0          12                 0
# 4             6.87       42450      0           9                 1
# ..             ...         ...    ...         ...               ...
# 296          11.60       33988      0           7                 1
# 297           5.90       60000      0           8                 0
# 298          11.00       87934      0          14                 0
# 299          12.50        9000      0           6                 1
# 300           5.90        5464      0           7                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                   1                        0                    1
# ...

# %%
x['Owner'].unique()
# Out:
# array([0, 1, 3])

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.45148844 0.0390693  0.000844   0.08612921 0.07814576 0.02284503
#  0.23218465 0.08929361]

# %%
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=5)

# %%
x_train.shape
# Out:
# (239, 8)

# %%
x_test.shape
# Out:
# (60, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
ypred = regressor.predict(x_test)

# %%
ypred
# Out:
# array([ 0.2179,  8.0668,  2.5595,  1.469 ,  4.344 , 15.5293,  4.2405,
#         0.5412, 14.9215,  1.2485,  2.935 ,  0.2007, 21.2009,  3.0975,
#         1.993 ,  2.4235,  4.82  , 19.7338,  7.3683,  7.3443,  6.5965,
#         1.2526, 10.3681,  4.2501,  0.6326,  5.0181,  3.274 , 19.7474,
#        11.8782,  0.2672,  6.7113,  1.0657,  2.879 ,  2.518 ,  4.1485,
#         4.689 ,  4.3195,  0.1968,  4.9212,  0.454 ,  5.747 ,  6.3265,
#        15.5347,  3.643 ,  5.1591,  1.0372,  1.5525,  6.0312,  5.1215,
#         9.3295,  4.564 , 13.0588,  6.3992,  7.3683,  0.7965,  1.1749,
#         2.791 ,  7.1662,  2.5405,  0.5795])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, ypred)
# Out:
# 0.8953110368174111

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters = {'n_estimators': [100,200,300,400,500,600,700,800,900,1000],
             'criterion': ['squared_error', 'absolute_error', 'poisson', 'friedma_mse'],
             'max_depth': [10,20,30,40,50],
             'min_samples_split': [2,5,10,20,50],
             'min_samples_leaf': [1,2,5,10],
             'max_features': ['auto', 'sqrt', 'log2']
             }

# %%
parameters
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
#  'criterion': ['squared_error', 'absolute_error', 'poisson', 'friedma_mse'],
#  'max_depth': [10, 20, 30, 40, 50],
#  'min_samples_split': [2, 5, 10, 20, 50],
#  'min_samples_leaf': [1, 2, 5, 10],
#  'max_features': ['auto', 'sqrt', 'log2']}

# %%
random_cv = RandomizedSearchCV(estimator=regressor, param_distributions=parameters, n_iter=10, scoring='neg_mean_absolute_error',
                              random_state=42, cv = 5, verbose = 2, n_jobs=-1)

# %%
random_cv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'absolute_error',
#                                                       'poisson',
#                                                       'friedma_mse'],
#                                         'max_depth': [10, 20, 30, 40, 50],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 20, 50],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
# ...

# %%
random_cv.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 30,
#  'criterion': 'poisson'}

# %%
random_cv.best_score_
# Out:
# -0.7656662097674152

# %%
predictions = random_cv.predict(x_test)

# %%
sns.displot(y_test-predictions)

# %%
plt.scatter(y_test, predictions)

# %%
from sklearn import metrics

# %%
print('MAE:',metrics.mean_absolute_error(y_test, predictions))
print('MAE:',metrics.mean_squared_error(y_test, predictions))
print('MAE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 1.0603411727796055
# MAE: 5.576229311103627
# MAE: 2.3614040973758867

# %%
x.head(5)
# Out:
#    Present_Price  Driven_kms  Owner  Age of car  Fuel_Type_Diesel  \
# 0           5.59       27000      0           9                 0
# 1           9.54       43000      0          10                 1
# 2           9.85        6900      0           6                 0
# 3           4.15        5200      0          12                 0
# 4           6.87       42450      0           9                 1
#
#    Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                 1                        0                    1
# 1                 0                        0                    1
# 2                 1                        0                    1
# 3                 1                        0                    1
# 4                 0                        0                    1

# %%
single_ob = np.array([9.5, 5000, 0.0, 5.0, 1.0, 0.0, 0.0, 1.0])
single_ob = single_ob.reshape(1,-1)

# %%
regressor.predict(single_ob)
# Out:
# array([8.4194])

# %%
cpp.head()
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  Age of car  \
# 0           3.35           5.59       27000      0           9
# 1           4.75           9.54       43000      0          10
# 2           7.25           9.85        6900      0           6
# 3           2.85           4.15        5200      0          12
# 4           4.60           6.87       42450      0           9
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0                 0                 1                        0
# 1                 1                 0                        0
# 2                 0                 1                        0
# 3                 0                 1                        0
# 4                 1                 0                        0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
